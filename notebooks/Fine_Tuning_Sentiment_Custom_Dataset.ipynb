# %% [markdown]
# <a href="https://colab.research.google.com/github/arthurziegler/transformers-for-NLP/blob/main/notebooks/Fine_Tuning_Sentiment_Custom_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.21.1-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 5.1 MB/s
# Collecting datasets
#   Downloading datasets-2.4.0-py3-none-any.whl (365 kB)
#      |████████████████████████████████| 365 kB 66.9 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 57.5 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.9.0-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 71.0 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 69.7 MB/s
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.7.1)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 74.2 MB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 72.4 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: urllib3, xxhash, tokenizers, responses, multiprocess, huggingface-hub, transformers, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.4.0 huggingface-hub-0.9.0 multiprocess-0.70.13 responses-0.18.0 tokenizers-0.12.1 transformers-4.21.1 urllib3-1.25.11 xxhash-3.0.0

# %%
# https://www.kaggle.com/crowdflower/twitter-airline-sentiment
# !wget -nc https://lazyprogrammer.me/course_files/AirlineTweets.csv
# Out:
# --2022-08-23 18:21:21--  https://lazyprogrammer.me/course_files/AirlineTweets.csv
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 104.21.23.210, 172.67.213.166, 2606:4700:3031::6815:17d2, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|104.21.23.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3421431 (3.3M) [text/csv]
# Saving to: ‘AirlineTweets.csv’
#
# AirlineTweets.csv   100%[===================>]   3.26M  3.09MB/s    in 1.1s
#
# 2022-08-23 18:21:22 (3.09 MB/s) - ‘AirlineTweets.csv’ saved [3421431/3421431]

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

import torch

from sklearn.metrics import f1_score, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
df_ = pd.read_csv('AirlineTweets.csv')

# %%
df_.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
df = df_[['airline_sentiment', 'text']].copy()

# %%
df.head()
# Out:
#   airline_sentiment                                               text
# 0           neutral                @VirginAmerica What @dhepburn said.
# 1          positive  @VirginAmerica plus you've added commercials t...
# 2           neutral  @VirginAmerica I didn't today... Must mean I n...
# 3          negative  @VirginAmerica it's really aggressive to blast...
# 4          negative  @VirginAmerica and it's a really big bad thing...

# %%
df['airline_sentiment'].hist()

# %%
target_map = {'positive': 1, 'negative': 0, 'neutral': 2}
df['target'] = df['airline_sentiment'].map(target_map)
df.head()
# Out:
#   airline_sentiment                                               text  target
# 0           neutral                @VirginAmerica What @dhepburn said.       2
# 1          positive  @VirginAmerica plus you've added commercials t...       1
# 2           neutral  @VirginAmerica I didn't today... Must mean I n...       2
# 3          negative  @VirginAmerica it's really aggressive to blast...       0
# 4          negative  @VirginAmerica and it's a really big bad thing...       0

# %%
df2 = df[['text', 'target']]
df2.columns = ['sentence', 'label']
df2.to_csv('data.csv', index=None)

# %%
# !head data.csv
# Out:
# sentence,label
# @VirginAmerica What @dhepburn said.,2
# @VirginAmerica plus you've added commercials to the experience... tacky.,1
# @VirginAmerica I didn't today... Must mean I need to take another trip!,2
# "@VirginAmerica it's really aggressive to blast obnoxious ""entertainment"" in your guests' faces &amp; they have little recourse",0
# @VirginAmerica and it's a really big bad thing about it,0
# "@VirginAmerica seriously would pay $30 a flight for seats that didn't have this playing.
# it's really the only bad thing about flying VA",0
# "@VirginAmerica yes, nearly every time I fly VX this “ear worm” won’t go away :)",1
# "@VirginAmerica Really missed a prime opportunity for Men Without Hats parody, there. https://t.co/mWpG7grEZP",2

# %%
from datasets import load_dataset
raw_dataset = load_dataset('csv', data_files = 'data.csv')
# Out:
# WARNING:datasets.builder:Using custom data configuration default-a592c45f9ca9077b
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-a592c45f9ca9077b/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-a592c45f9ca9077b/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
raw_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 14640
#     })
# })

# %%
split = raw_dataset['train'].train_test_split(test_size=0.3, seed=42)
split
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 10248
#     })
#     test: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 4392
#     })
# })

# %%
#if we have multiple datasets
#load_dataset('csv', data_files=['file1.csv, 'file2.csv])

# %%
#if we already have a train-test split:
#load_dataset(
#    'csv',
#    data_files={'train': ['train1.csv', 'train2.csv'],
#                'test': 'test.csv'}
#)

# %%
checkpoint = 'distilbert-base-cased'

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# Downloading tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/411 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/208k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/426k [00:00<?, ?B/s]

# %%
def tokenize_fn(batch):
    return tokenizer(batch['sentence'], truncation=True)

# %%
tokenized_datasets = split.map(tokenize_fn, batched=True)
# Out:
#   0%|          | 0/11 [00:00<?, ?ba/s]
#   0%|          | 0/5 [00:00<?, ?ba/s]

# %%
from transformers import AutoModelForSequenceClassification, Trainer, TrainingArguments

# %%
model = AutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=3)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/251M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-cased were not used when initializing DistilBertForSequenceClassification: ['vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['classifier.bias', 'pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# !pip install torchinfo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchinfo
#   Downloading torchinfo-1.7.0-py3-none-any.whl (22 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.7.0

# %%
from torchinfo import summary

# %%
summary(model)
# Out:
# ================================================================================
# Layer (type:depth-idx)                                  Param #
# ================================================================================
# DistilBertForSequenceClassification                     --
# ├─DistilBertModel: 1-1                                  --
# │    └─Embeddings: 2-1                                  --
# │    │    └─Embedding: 3-1                              22,268,928
# │    │    └─Embedding: 3-2                              393,216
# │    │    └─LayerNorm: 3-3                              1,536
# │    │    └─Dropout: 3-4                                --
# │    └─Transformer: 2-2                                 --
# │    │    └─ModuleList: 3-5                             42,527,232
# ├─Linear: 1-2                                           590,592
# ├─Linear: 1-3                                           2,307
# ├─Dropout: 1-4                                          --
# ================================================================================
# Total params: 65,783,811
# Trainable params: 65,783,811
# Non-trainable params: 0
# ================================================================================

# %%
training_args = TrainingArguments(
    output_dir='training_dir',
    evaluation_strategy='epoch',
    save_strategy='epoch',
    num_train_epochs=3,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=64
)

# %%
def compute_metrics(logits_and_labels):
    logits, labels = logits_and_labels
    predictions = np.argmax(logits, axis=-1)
    acc = np.mean(predictions == labels)
    f1 = f1_score(labels, predictions, average='macro')
    return {'accuracy': acc, 'f1': f1}

# %%
trainer = Trainer(
    model,
    training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 10248
#   Num Epochs = 3
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1923
#     <div>
#
#       <progress value='1923' max='1923' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1923/1923 03:17, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.550100</td>
#       <td>0.434590</td>
#       <td>0.828552</td>
#       <td>0.771162</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.349100</td>
#       <td>0.487368</td>
#       <td>0.828097</td>
#       <td>0.781588</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.239900</td>
#       <td>0.637286</td>
#       <td>0.836293</td>
#       <td>0.781713</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 4392
#   Batch size = 64
# Saving model checkpoint to training_dir/checkpoint-641
# Configuration saved in training_dir/checkpoint-641/config.json
# Model weights saved in training_dir/checkpoint-641/pytorch_model.bin
# tokenizer config file saved in training_dir/checkpoint-641/tokenizer_config.json
# Special tokens file saved in training_dir/checkpoint-641/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 4392
#   Batch size = 64
# Saving model checkpoint to training_dir/checkpoint-1282
# Configuration saved in training_dir/checkpoint-1282/config.json
# Model weights saved in training_dir/checkpoint-1282/pytorch_model.bin
# tokenizer config file saved in training_dir/checkpoint-1282/tokenizer_config.json
# Special tokens file saved in training_dir/checkpoint-1282/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 4392
#   Batch size = 64
# Saving model checkpoint to training_dir/checkpoint-1923
# Configuration saved in training_dir/checkpoint-1923/config.json
# Model weights saved in training_dir/checkpoint-1923/pytorch_model.bin
# tokenizer config file saved in training_dir/checkpoint-1923/tokenizer_config.json
# Special tokens file saved in training_dir/checkpoint-1923/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=1923, training_loss=0.3317309502072466, metrics={'train_runtime': 201.1487, 'train_samples_per_second': 152.842, 'train_steps_per_second': 9.56, 'total_flos': 388376501242176.0, 'train_loss': 0.3317309502072466, 'epoch': 3.0})

# %%
# !ls training_dir
# Out:
# checkpoint-1282  checkpoint-1923  checkpoint-641  runs

# %%
from transformers import pipeline

# %%
savedmodel = pipeline('text-classification',
                      model='training_dir/checkpoint-1282',
                      device=0)
# Out:
# loading configuration file training_dir/checkpoint-1282/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "training_dir/checkpoint-1282",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForSequenceClassification"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "problem_type": "single_label_classification",
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.21.1",
#   "vocab_size": 28996
# }
#
# loading configuration file training_dir/checkpoint-1282/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "training_dir/checkpoint-1282",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForSequenceClassification"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "problem_type": "single_label_classification",
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.21.1",
#   "vocab_size": 28996
# }
#
# loading weights file training_dir/checkpoint-1282/pytorch_model.bin
# All model checkpoint weights were used when initializing DistilBertForSequenceClassification.
#
# All the weights of DistilBertForSequenceClassification were initialized from the model checkpoint at training_dir/checkpoint-1282.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use DistilBertForSequenceClassification for predictions without further training.
# Didn't find file training_dir/checkpoint-1282/added_tokens.json. We won't load it.
# loading file training_dir/checkpoint-1282/vocab.txt
# loading file training_dir/checkpoint-1282/tokenizer.json
# loading file None
# loading file training_dir/checkpoint-1282/special_tokens_map.json
# loading file training_dir/checkpoint-1282/tokenizer_config.json

# %%
split['test']
# Out:
# Dataset({
#     features: ['sentence', 'label'],
#     num_rows: 4392
# })

# %%
test_pred= savedmodel(split['test']['sentence'])
test_pred
# Out:
# Disabling tokenizer parallelism, we're using DataLoader multithreading already
# [{'label': 'LABEL_1', 'score': 0.9478098154067993},
#  {'label': 'LABEL_1', 'score': 0.9689260125160217},
#  {'label': 'LABEL_1', 'score': 0.4712720811367035},
#  {'label': 'LABEL_1', 'score': 0.8951069712638855},
#  {'label': 'LABEL_2', 'score': 0.8188455700874329},
#  {'label': 'LABEL_0', 'score': 0.9956847429275513},
#  {'label': 'LABEL_2', 'score': 0.9546842575073242},
#  {'label': 'LABEL_2', 'score': 0.9765600562095642},
#  {'label': 'LABEL_1', 'score': 0.6068569421768188},
#  {'label': 'LABEL_0', 'score': 0.9937353730201721},
#  {'label': 'LABEL_0', 'score': 0.9736698865890503},
#  {'label': 'LABEL_0', 'score': 0.9949788451194763},
#  {'label': 'LABEL_1', 'score': 0.9676230549812317},
#  {'label': 'LABEL_0', 'score': 0.9889955520629883},
#  {'label': 'LABEL_2', 'score': 0.9801437258720398},
#  {'label': 'LABEL_2', 'score': 0.6282762885093689},
#  {'label': 'LABEL_2', 'score': 0.4245862662792206},
#  {'label': 'LABEL_0', 'score': 0.996658444404602},
#  {'label': 'LABEL_0', 'score': 0.9291214346885681},
#  {'label': 'LABEL_0', 'score': 0.9923844337463379},
#  {'label': 'LABEL_2', 'score': 0.9660822153091431},
#  {'label': 'LABEL_2', 'score': 0.7913658022880554},
#  {'label': 'LABEL_0', 'score': 0.6277598738670349},
#  {'label': 'LABEL_0', 'score': 0.7121397256851196},
#  {'label': 'LABEL_0', 'score': 0.9904161691665649},
#  {'label': 'LABEL_0', 'score': 0.6281303763389587},
#  {'label': 'LABEL_0', 'score': 0.9965460896492004},
#  {'label': 'LABEL_0', 'score': 0.9959502220153809},
#  {'label': 'LABEL_0', 'score': 0.9963006973266602},
#  {'label': 'LABEL_0', 'score': 0.9915891289710999},
#  {'label': 'LABEL_0', 'score': 0.9965586066246033},
#  {'label': 'LABEL_1', 'score': 0.636554479598999},
#  {'label': 'LABEL_0', 'score': 0.9960864782333374},
#  {'label': 'LABEL_0', 'score': 0.9970754384994507},
#  {'label': 'LABEL_1', 'score': 0.95339035987854},
#  {'label': 'LABEL_0', 'score': 0.9962345957756042},
#  {'label': 'LABEL_2', 'score': 0.3677102029323578},
#  {'label': 'LABEL_0', 'score': 0.9709194302558899},
#  {'label': 'LABEL_0', 'score': 0.9768361449241638},
#  {'label': 'LABEL_2', 'score': 0.5505242943763733},
#  {'label': 'LABEL_0', 'score': 0.9937506318092346},
#  {'label': 'LABEL_0', 'score': 0.9612553119659424},
#  {'label': 'LABEL_0', 'score': 0.9916754961013794},
#  {'label': 'LABEL_0', 'score': 0.5077252984046936},
#  {'label': 'LABEL_1', 'score': 0.7090346813201904},
#  {'label': 'LABEL_2', 'score': 0.6251030564308167},
#  {'label': 'LABEL_0', 'score': 0.9172653555870056},
#  {'label': 'LABEL_1', 'score': 0.767371416091919},
#  {'label': 'LABEL_0', 'score': 0.9945032596588135},
#  {'label': 'LABEL_0', 'score': 0.996877908706665},
#  {'label': 'LABEL_0', 'score': 0.9331876635551453},
#  {'label': 'LABEL_0', 'score': 0.931081235408783},
#  {'label': 'LABEL_0', 'score': 0.9153593182563782},
#  {'label': 'LABEL_0', 'score': 0.9966765642166138},
#  {'label': 'LABEL_0', 'score': 0.9954906105995178},
#  {'label': 'LABEL_0', 'score': 0.9956747889518738},
#  {'label': 'LABEL_0', 'score': 0.5138065814971924},
#  {'label': 'LABEL_2', 'score': 0.9714183211326599},
#  {'label': 'LABEL_0', 'score': 0.9956238865852356},
#  {'label': 'LABEL_1', 'score': 0.5672171115875244},
#  {'label': 'LABEL_0', 'score': 0.9842326641082764},
#  {'label': 'LABEL_0', 'score': 0.9931644797325134},
#  {'label': 'LABEL_0', 'score': 0.9905430674552917},
#  {'label': 'LABEL_0', 'score': 0.9865958094596863},
#  {'label': 'LABEL_0', 'score': 0.8652698993682861},
#  {'label': 'LABEL_2', 'score': 0.9812082052230835},
#  {'label': 'LABEL_0', 'score': 0.9880121946334839},
#  {'label': 'LABEL_0', 'score': 0.9960487484931946},
#  {'label': 'LABEL_0', 'score': 0.9964889287948608},
#  {'label': 'LABEL_0', 'score': 0.861718475818634},
#  {'label': 'LABEL_0', 'score': 0.738848865032196},
#  {'label': 'LABEL_0', 'score': 0.9626849889755249},
#  {'label': 'LABEL_0', 'score': 0.8434834480285645},
#  {'label': 'LABEL_0', 'score': 0.9643917083740234},
#  {'label': 'LABEL_2', 'score': 0.7296801805496216},
#  {'label': 'LABEL_0', 'score': 0.4806601107120514},
#  {'label': 'LABEL_0', 'score': 0.9962977766990662},
#  {'label': 'LABEL_0', 'score': 0.9553820490837097},
#  {'label': 'LABEL_0', 'score': 0.9922629594802856},
#  {'label': 'LABEL_0', 'score': 0.9197991490364075},
#  {'label': 'LABEL_0', 'score': 0.9968041181564331},
#  {'label': 'LABEL_0', 'score': 0.9423773884773254},
#  {'label': 'LABEL_1', 'score': 0.9454262256622314},
#  {'label': 'LABEL_0', 'score': 0.8616040349006653},
#  {'label': 'LABEL_1', 'score': 0.9178526401519775},
#  {'label': 'LABEL_2', 'score': 0.9727336764335632},
#  {'label': 'LABEL_0', 'score': 0.9958563446998596},
#  {'label': 'LABEL_0', 'score': 0.986542820930481},
#  {'label': 'LABEL_0', 'score': 0.963034451007843},
#  {'label': 'LABEL_2', 'score': 0.7447120547294617},
#  {'label': 'LABEL_0', 'score': 0.7250739336013794},
#  {'label': 'LABEL_0', 'score': 0.9788426160812378},
#  {'label': 'LABEL_0', 'score': 0.991663932800293},
#  {'label': 'LABEL_1', 'score': 0.8840007185935974},
#  {'label': 'LABEL_0', 'score': 0.9719297289848328},
#  {'label': 'LABEL_0', 'score': 0.988160252571106},
#  {'label': 'LABEL_0', 'score': 0.9958620071411133},
#  {'label': 'LABEL_0', 'score': 0.9958691000938416},
#  {'label': 'LABEL_0', 'score': 0.9659023880958557},
#  {'label': 'LABEL_0', 'score': 0.988903820514679},
#  {'label': 'LABEL_0', 'score': 0.9964290261268616},
#  {'label': 'LABEL_2', 'score': 0.9824255108833313},
#  {'label': 'LABEL_2', 'score': 0.9596869349479675},
#  {'label': 'LABEL_2', 'score': 0.9551051259040833},
#  {'label': 'LABEL_2', 'score': 0.9210420846939087},
#  {'label': 'LABEL_0', 'score': 0.9961947202682495},
#  {'label': 'LABEL_0', 'score': 0.7703549861907959},
#  {'label': 'LABEL_0', 'score': 0.9932757616043091},
#  {'label': 'LABEL_0', 'score': 0.9588268399238586},
#  {'label': 'LABEL_0', 'score': 0.9967131614685059},
#  {'label': 'LABEL_0', 'score': 0.9837799668312073},
#  {'label': 'LABEL_0', 'score': 0.995509147644043},
#  {'label': 'LABEL_0', 'score': 0.9859350919723511},
#  {'label': 'LABEL_2', 'score': 0.6322174668312073},
#  {'label': 'LABEL_0', 'score': 0.9882327914237976},
#  {'label': 'LABEL_2', 'score': 0.9587581157684326},
#  {'label': 'LABEL_0', 'score': 0.9844807386398315},
#  {'label': 'LABEL_2', 'score': 0.9072542786598206},
#  {'label': 'LABEL_0', 'score': 0.9955036044120789},
#  {'label': 'LABEL_2', 'score': 0.9585300087928772},
#  {'label': 'LABEL_2', 'score': 0.9686247706413269},
#  {'label': 'LABEL_2', 'score': 0.9555127620697021},
#  {'label': 'LABEL_2', 'score': 0.9514991641044617},
#  {'label': 'LABEL_2', 'score': 0.9639459848403931},
#  {'label': 'LABEL_0', 'score': 0.9875257015228271},
#  {'label': 'LABEL_0', 'score': 0.9968993663787842},
#  {'label': 'LABEL_0', 'score': 0.9484678506851196},
#  {'label': 'LABEL_0', 'score': 0.9963042736053467},
#  {'label': 'LABEL_2', 'score': 0.8023084402084351},
#  {'label': 'LABEL_0', 'score': 0.9956895709037781},
#  {'label': 'LABEL_1', 'score': 0.8935747146606445},
#  {'label': 'LABEL_0', 'score': 0.9964978098869324},
#  {'label': 'LABEL_0', 'score': 0.9206153154373169},
#  {'label': 'LABEL_1', 'score': 0.9736088514328003},
#  {'label': 'LABEL_2', 'score': 0.963655412197113},
#  {'label': 'LABEL_0', 'score': 0.9659678936004639},
#  {'label': 'LABEL_0', 'score': 0.9952616691589355},
#  {'label': 'LABEL_0', 'score': 0.9606524109840393},
#  {'label': 'LABEL_0', 'score': 0.995267927646637},
#  {'label': 'LABEL_0', 'score': 0.9966230392456055},
#  {'label': 'LABEL_0', 'score': 0.9766918420791626},
#  {'label': 'LABEL_0', 'score': 0.9849770069122314},
#  {'label': 'LABEL_0', 'score': 0.991306722164154},
#  {'label': 'LABEL_0', 'score': 0.9911608695983887},
#  {'label': 'LABEL_2', 'score': 0.8941309452056885},
#  {'label': 'LABEL_2', 'score': 0.9474472403526306},
#  {'label': 'LABEL_2', 'score': 0.9531437754631042},
#  {'label': 'LABEL_0', 'score': 0.9965000152587891},
#  {'label': 'LABEL_0', 'score': 0.9923169612884521},
#  {'label': 'LABEL_0', 'score': 0.9966641068458557},
#  {'label': 'LABEL_0', 'score': 0.995848536491394},
#  {'label': 'LABEL_2', 'score': 0.8724229335784912},
#  {'label': 'LABEL_2', 'score': 0.9666932225227356},
#  {'label': 'LABEL_2', 'score': 0.956169605255127},
#  {'label': 'LABEL_1', 'score': 0.9306082725524902},
#  {'label': 'LABEL_2', 'score': 0.8121945261955261},
#  {'label': 'LABEL_0', 'score': 0.9717220067977905},
#  {'label': 'LABEL_0', 'score': 0.9744669198989868},
#  {'label': 'LABEL_0', 'score': 0.9952203631401062},
#  {'label': 'LABEL_0', 'score': 0.9959622025489807},
#  {'label': 'LABEL_2', 'score': 0.8347828984260559},
#  {'label': 'LABEL_0', 'score': 0.9967343807220459},
#  {'label': 'LABEL_1', 'score': 0.8314400315284729},
#  {'label': 'LABEL_0', 'score': 0.9946721196174622},
#  {'label': 'LABEL_0', 'score': 0.7364838719367981},
#  {'label': 'LABEL_0', 'score': 0.5562450885772705},
#  {'label': 'LABEL_0', 'score': 0.9960557222366333},
#  {'label': 'LABEL_0', 'score': 0.9942565560340881},
#  {'label': 'LABEL_2', 'score': 0.8891611099243164},
#  {'label': 'LABEL_2', 'score': 0.9853991270065308},
#  {'label': 'LABEL_0', 'score': 0.9952687621116638},
#  {'label': 'LABEL_0', 'score': 0.8273270130157471},
#  {'label': 'LABEL_0', 'score': 0.8534881472587585},
#  {'label': 'LABEL_2', 'score': 0.9373010396957397},
#  {'label': 'LABEL_1', 'score': 0.5629816651344299},
#  {'label': 'LABEL_1', 'score': 0.6538602113723755},
#  {'label': 'LABEL_0', 'score': 0.5491068959236145},
#  {'label': 'LABEL_0', 'score': 0.9969207048416138},
#  {'label': 'LABEL_0', 'score': 0.9921259880065918},
#  {'label': 'LABEL_0', 'score': 0.9726340770721436},
#  {'label': 'LABEL_0', 'score': 0.9756284952163696},
#  {'label': 'LABEL_0', 'score': 0.6634507775306702},
#  {'label': 'LABEL_0', 'score': 0.9970943927764893},
#  {'label': 'LABEL_0', 'score': 0.9946845173835754},
#  {'label': 'LABEL_0', 'score': 0.9966572523117065},
#  {'label': 'LABEL_2', 'score': 0.8435675501823425},
#  {'label': 'LABEL_2', 'score': 0.8534477353096008},
#  {'label': 'LABEL_0', 'score': 0.9962460398674011},
#  {'label': 'LABEL_1', 'score': 0.9789080023765564},
#  {'label': 'LABEL_0', 'score': 0.8405150771141052},
#  {'label': 'LABEL_0', 'score': 0.9251284003257751},
#  {'label': 'LABEL_0', 'score': 0.9924099445343018},
#  {'label': 'LABEL_0', 'score': 0.9824070930480957},
#  {'label': 'LABEL_0', 'score': 0.7159536480903625},
#  {'label': 'LABEL_1', 'score': 0.6430693864822388},
#  {'label': 'LABEL_2', 'score': 0.9715589284896851},
#  {'label': 'LABEL_1', 'score': 0.9681963324546814},
#  {'label': 'LABEL_0', 'score': 0.7683852910995483},
#  {'label': 'LABEL_0', 'score': 0.9958634376525879},
#  {'label': 'LABEL_0', 'score': 0.9888279438018799},
#  {'label': 'LABEL_2', 'score': 0.7946439385414124},
#  {'label': 'LABEL_2', 'score': 0.5883809924125671},
#  {'label': 'LABEL_2', 'score': 0.9473332166671753},
#  {'label': 'LABEL_0', 'score': 0.9964696168899536},
#  {'label': 'LABEL_0', 'score': 0.9946194887161255},
#  {'label': 'LABEL_1', 'score': 0.9400309920310974},
#  {'label': 'LABEL_2', 'score': 0.9812526106834412},
#  {'label': 'LABEL_0', 'score': 0.9966471791267395},
#  {'label': 'LABEL_0', 'score': 0.9940398931503296},
#  {'label': 'LABEL_0', 'score': 0.8848379254341125},
#  {'label': 'LABEL_1', 'score': 0.4174169898033142},
#  {'label': 'LABEL_2', 'score': 0.9685553908348083},
#  {'label': 'LABEL_1', 'score': 0.9615308046340942},
#  {'label': 'LABEL_2', 'score': 0.8329553008079529},
#  {'label': 'LABEL_0', 'score': 0.9789295792579651},
#  {'label': 'LABEL_2', 'score': 0.9847229719161987},
#  {'label': 'LABEL_2', 'score': 0.9873203039169312},
#  {'label': 'LABEL_0', 'score': 0.9935476183891296},
#  {'label': 'LABEL_2', 'score': 0.9798866510391235},
#  {'label': 'LABEL_2', 'score': 0.880776047706604},
#  {'label': 'LABEL_0', 'score': 0.6394422054290771},
#  {'label': 'LABEL_0', 'score': 0.9959932565689087},
#  {'label': 'LABEL_0', 'score': 0.9695188999176025},
#  {'label': 'LABEL_2', 'score': 0.9506276249885559},
#  {'label': 'LABEL_1', 'score': 0.9467227458953857},
#  {'label': 'LABEL_0', 'score': 0.8293388485908508},
#  {'label': 'LABEL_2', 'score': 0.6754193305969238},
#  {'label': 'LABEL_0', 'score': 0.9837289452552795},
#  {'label': 'LABEL_0', 'score': 0.9835572242736816},
#  {'label': 'LABEL_0', 'score': 0.979780912399292},
#  {'label': 'LABEL_2', 'score': 0.6180600523948669},
#  {'label': 'LABEL_0', 'score': 0.9012053608894348},
#  {'label': 'LABEL_0', 'score': 0.9916476011276245},
#  {'label': 'LABEL_0', 'score': 0.9949848651885986},
#  {'label': 'LABEL_0', 'score': 0.9852584004402161},
#  {'label': 'LABEL_1', 'score': 0.8449575901031494},
#  {'label': 'LABEL_0', 'score': 0.9555463790893555},
#  {'label': 'LABEL_0', 'score': 0.9112915396690369},
#  {'label': 'LABEL_0', 'score': 0.9963770508766174},
#  {'label': 'LABEL_0', 'score': 0.9822205901145935},
#  {'label': 'LABEL_0', 'score': 0.9513787627220154},
#  {'label': 'LABEL_2', 'score': 0.9016991257667542},
#  {'label': 'LABEL_0', 'score': 0.5574402809143066},
#  {'label': 'LABEL_1', 'score': 0.5443597435951233},
#  {'label': 'LABEL_0', 'score': 0.9970505237579346},
#  {'label': 'LABEL_0', 'score': 0.9628955125808716},
#  {'label': 'LABEL_0', 'score': 0.8869327306747437},
#  {'label': 'LABEL_2', 'score': 0.5924599170684814},
#  {'label': 'LABEL_0', 'score': 0.8461808562278748},
#  {'label': 'LABEL_2', 'score': 0.9651618003845215},
#  {'label': 'LABEL_0', 'score': 0.9960071444511414},
#  {'label': 'LABEL_0', 'score': 0.9658828973770142},
#  {'label': 'LABEL_0', 'score': 0.9964855909347534},
#  {'label': 'LABEL_0', 'score': 0.9951016306877136},
#  {'label': 'LABEL_0', 'score': 0.9942575693130493},
#  {'label': 'LABEL_0', 'score': 0.7912885546684265},
#  {'label': 'LABEL_0', 'score': 0.5324105620384216},
#  {'label': 'LABEL_0', 'score': 0.9962213039398193},
#  {'label': 'LABEL_0', 'score': 0.9701529741287231},
#  {'label': 'LABEL_0', 'score': 0.6117760539054871},
#  {'label': 'LABEL_1', 'score': 0.9681046009063721},
#  {'label': 'LABEL_0', 'score': 0.9923354983329773},
#  {'label': 'LABEL_0', 'score': 0.9924721717834473},
#  {'label': 'LABEL_1', 'score': 0.9822657108306885},
#  {'label': 'LABEL_1', 'score': 0.5161675810813904},
#  {'label': 'LABEL_0', 'score': 0.9321226477622986},
#  {'label': 'LABEL_0', 'score': 0.9930520057678223},
#  {'label': 'LABEL_2', 'score': 0.5505403876304626},
#  {'label': 'LABEL_0', 'score': 0.9113360047340393},
#  {'label': 'LABEL_1', 'score': 0.9675949811935425},
#  {'label': 'LABEL_0', 'score': 0.9959402084350586},
#  {'label': 'LABEL_0', 'score': 0.9827460050582886},
#  {'label': 'LABEL_2', 'score': 0.6877338290214539},
#  {'label': 'LABEL_0', 'score': 0.6563828587532043},
#  {'label': 'LABEL_0', 'score': 0.678387463092804},
#  {'label': 'LABEL_1', 'score': 0.8587484955787659},
#  {'label': 'LABEL_0', 'score': 0.9971145391464233},
#  {'label': 'LABEL_2', 'score': 0.9050970673561096},
#  {'label': 'LABEL_2', 'score': 0.9827376008033752},
#  {'label': 'LABEL_0', 'score': 0.9727464914321899},
#  {'label': 'LABEL_0', 'score': 0.9957901835441589},
#  {'label': 'LABEL_0', 'score': 0.9931210875511169},
#  {'label': 'LABEL_2', 'score': 0.9248945116996765},
#  {'label': 'LABEL_0', 'score': 0.989267110824585},
#  {'label': 'LABEL_1', 'score': 0.9548763632774353},
#  {'label': 'LABEL_2', 'score': 0.8605431318283081},
#  {'label': 'LABEL_0', 'score': 0.9811393618583679},
#  {'label': 'LABEL_0', 'score': 0.9950278401374817},
#  {'label': 'LABEL_0', 'score': 0.9945658445358276},
#  {'label': 'LABEL_0', 'score': 0.9960676431655884},
#  {'label': 'LABEL_0', 'score': 0.9693815112113953},
#  {'label': 'LABEL_0', 'score': 0.9956051707267761},
#  {'label': 'LABEL_2', 'score': 0.9616464972496033},
#  {'label': 'LABEL_2', 'score': 0.870790958404541},
#  {'label': 'LABEL_0', 'score': 0.9384680390357971},
#  {'label': 'LABEL_0', 'score': 0.8929064869880676},
#  {'label': 'LABEL_2', 'score': 0.9094259738922119},
#  {'label': 'LABEL_2', 'score': 0.9806217551231384},
#  {'label': 'LABEL_0', 'score': 0.9967682361602783},
#  {'label': 'LABEL_0', 'score': 0.9759456515312195},
#  {'label': 'LABEL_0', 'score': 0.9950143694877625},
#  {'label': 'LABEL_2', 'score': 0.9584767818450928},
#  {'label': 'LABEL_2', 'score': 0.8312419652938843},
#  {'label': 'LABEL_0', 'score': 0.992609441280365},
#  {'label': 'LABEL_2', 'score': 0.9604004621505737},
#  {'label': 'LABEL_0', 'score': 0.9066801071166992},
#  {'label': 'LABEL_1', 'score': 0.9127498269081116},
#  {'label': 'LABEL_2', 'score': 0.9606900215148926},
#  {'label': 'LABEL_2', 'score': 0.8292734026908875},
#  {'label': 'LABEL_0', 'score': 0.994271993637085},
#  {'label': 'LABEL_0', 'score': 0.9741266369819641},
#  {'label': 'LABEL_0', 'score': 0.9895842671394348},
#  {'label': 'LABEL_0', 'score': 0.9967151880264282},
#  {'label': 'LABEL_2', 'score': 0.896918535232544},
#  {'label': 'LABEL_0', 'score': 0.9812774062156677},
#  {'label': 'LABEL_1', 'score': 0.8331010937690735},
#  {'label': 'LABEL_2', 'score': 0.5547437071800232},
#  {'label': 'LABEL_0', 'score': 0.616010844707489},
#  {'label': 'LABEL_0', 'score': 0.9490105509757996},
#  {'label': 'LABEL_0', 'score': 0.9943475127220154},
#  {'label': 'LABEL_0', 'score': 0.9927771091461182},
#  {'label': 'LABEL_0', 'score': 0.9357759356498718},
#  {'label': 'LABEL_2', 'score': 0.5584018230438232},
#  {'label': 'LABEL_0', 'score': 0.5444897413253784},
#  {'label': 'LABEL_0', 'score': 0.9767151474952698},
#  {'label': 'LABEL_0', 'score': 0.760125458240509},
#  {'label': 'LABEL_2', 'score': 0.4657214283943176},
#  {'label': 'LABEL_0', 'score': 0.9806281328201294},
#  {'label': 'LABEL_0', 'score': 0.5509635806083679},
#  {'label': 'LABEL_0', 'score': 0.9679175019264221},
#  {'label': 'LABEL_2', 'score': 0.9784477353096008},
#  {'label': 'LABEL_0', 'score': 0.9955703616142273},
#  {'label': 'LABEL_0', 'score': 0.9807302951812744},
#  {'label': 'LABEL_2', 'score': 0.6014628410339355},
#  {'label': 'LABEL_0', 'score': 0.9941068887710571},
#  {'label': 'LABEL_0', 'score': 0.9940616488456726},
#  {'label': 'LABEL_2', 'score': 0.8458702564239502},
#  {'label': 'LABEL_0', 'score': 0.9888629913330078},
#  {'label': 'LABEL_2', 'score': 0.7919343113899231},
#  {'label': 'LABEL_1', 'score': 0.948095440864563},
#  {'label': 'LABEL_0', 'score': 0.8044078350067139},
#  {'label': 'LABEL_0', 'score': 0.9929231405258179},
#  {'label': 'LABEL_0', 'score': 0.9915480017662048},
#  {'label': 'LABEL_0', 'score': 0.9438157677650452},
#  {'label': 'LABEL_0', 'score': 0.968505859375},
#  {'label': 'LABEL_2', 'score': 0.862587571144104},
#  {'label': 'LABEL_0', 'score': 0.9171690344810486},
#  {'label': 'LABEL_0', 'score': 0.8080030679702759},
#  {'label': 'LABEL_0', 'score': 0.9924707412719727},
#  {'label': 'LABEL_1', 'score': 0.9722489714622498},
#  {'label': 'LABEL_2', 'score': 0.9669452905654907},
#  {'label': 'LABEL_1', 'score': 0.734257698059082},
#  {'label': 'LABEL_1', 'score': 0.8765461444854736},
#  {'label': 'LABEL_0', 'score': 0.9958368539810181},
#  {'label': 'LABEL_2', 'score': 0.9843865036964417},
#  {'label': 'LABEL_2', 'score': 0.9348284006118774},
#  {'label': 'LABEL_0', 'score': 0.738639771938324},
#  {'label': 'LABEL_1', 'score': 0.8137322068214417},
#  {'label': 'LABEL_2', 'score': 0.9183117747306824},
#  {'label': 'LABEL_0', 'score': 0.9943220615386963},
#  {'label': 'LABEL_0', 'score': 0.7827833294868469},
#  {'label': 'LABEL_0', 'score': 0.9832919239997864},
#  {'label': 'LABEL_0', 'score': 0.9885627031326294},
#  {'label': 'LABEL_0', 'score': 0.534196138381958},
#  {'label': 'LABEL_2', 'score': 0.9160410165786743},
#  {'label': 'LABEL_0', 'score': 0.9961915016174316},
#  {'label': 'LABEL_0', 'score': 0.9968011379241943},
#  {'label': 'LABEL_1', 'score': 0.9609870910644531},
#  {'label': 'LABEL_0', 'score': 0.9226471185684204},
#  {'label': 'LABEL_0', 'score': 0.6993495225906372},
#  {'label': 'LABEL_2', 'score': 0.9472589492797852},
#  {'label': 'LABEL_0', 'score': 0.9934804439544678},
#  {'label': 'LABEL_1', 'score': 0.9684938192367554},
#  {'label': 'LABEL_0', 'score': 0.9933189153671265},
#  {'label': 'LABEL_1', 'score': 0.5416314601898193},
#  {'label': 'LABEL_0', 'score': 0.9952406883239746},
#  {'label': 'LABEL_2', 'score': 0.8365352153778076},
#  {'label': 'LABEL_0', 'score': 0.7209040522575378},
#  {'label': 'LABEL_1', 'score': 0.9765812158584595},
#  {'label': 'LABEL_2', 'score': 0.9781896471977234},
#  {'label': 'LABEL_0', 'score': 0.9960196614265442},
#  {'label': 'LABEL_0', 'score': 0.9913454055786133},
#  {'label': 'LABEL_0', 'score': 0.45472976565361023},
#  {'label': 'LABEL_0', 'score': 0.9861871004104614},
#  {'label': 'LABEL_1', 'score': 0.9810295701026917},
#  {'label': 'LABEL_0', 'score': 0.798884391784668},
#  {'label': 'LABEL_0', 'score': 0.9964057207107544},
#  {'label': 'LABEL_1', 'score': 0.8699160218238831},
#  {'label': 'LABEL_1', 'score': 0.9801121950149536},
#  {'label': 'LABEL_0', 'score': 0.7781621813774109},
#  {'label': 'LABEL_0', 'score': 0.9951682090759277},
#  {'label': 'LABEL_0', 'score': 0.9964306950569153},
#  {'label': 'LABEL_0', 'score': 0.9825332760810852},
#  {'label': 'LABEL_0', 'score': 0.9729117751121521},
#  {'label': 'LABEL_1', 'score': 0.9176453351974487},
#  {'label': 'LABEL_0', 'score': 0.9692291021347046},
#  {'label': 'LABEL_0', 'score': 0.9948683977127075},
#  {'label': 'LABEL_1', 'score': 0.8625256419181824},
#  {'label': 'LABEL_0', 'score': 0.9965170621871948},
#  {'label': 'LABEL_0', 'score': 0.7793985605239868},
#  {'label': 'LABEL_2', 'score': 0.5830652117729187},
#  {'label': 'LABEL_2', 'score': 0.6271733045578003},
#  {'label': 'LABEL_0', 'score': 0.9699808955192566},
#  {'label': 'LABEL_0', 'score': 0.9038837552070618},
#  {'label': 'LABEL_0', 'score': 0.9886394739151001},
#  {'label': 'LABEL_0', 'score': 0.9947739243507385},
#  {'label': 'LABEL_2', 'score': 0.5353074669837952},
#  {'label': 'LABEL_0', 'score': 0.9629243612289429},
#  {'label': 'LABEL_2', 'score': 0.9819186925888062},
#  {'label': 'LABEL_0', 'score': 0.9955112934112549},
#  {'label': 'LABEL_0', 'score': 0.9869059920310974},
#  {'label': 'LABEL_2', 'score': 0.8841924667358398},
#  {'label': 'LABEL_0', 'score': 0.9824564456939697},
#  {'label': 'LABEL_0', 'score': 0.8775664567947388},
#  {'label': 'LABEL_0', 'score': 0.7236531972885132},
#  {'label': 'LABEL_0', 'score': 0.6569970846176147},
#  {'label': 'LABEL_2', 'score': 0.9622910618782043},
#  {'label': 'LABEL_2', 'score': 0.9697866439819336},
#  {'label': 'LABEL_2', 'score': 0.9680630564689636},
#  {'label': 'LABEL_0', 'score': 0.9869647026062012},
#  {'label': 'LABEL_2', 'score': 0.9817536473274231},
#  {'label': 'LABEL_2', 'score': 0.9472955465316772},
#  {'label': 'LABEL_0', 'score': 0.950569212436676},
#  {'label': 'LABEL_1', 'score': 0.9616963267326355},
#  {'label': 'LABEL_0', 'score': 0.9851400256156921},
#  {'label': 'LABEL_0', 'score': 0.7860466241836548},
#  {'label': 'LABEL_2', 'score': 0.5068559646606445},
#  {'label': 'LABEL_0', 'score': 0.823917806148529},
#  {'label': 'LABEL_0', 'score': 0.9954505562782288},
#  {'label': 'LABEL_0', 'score': 0.9746010899543762},
#  {'label': 'LABEL_2', 'score': 0.8810595870018005},
#  {'label': 'LABEL_0', 'score': 0.9615906476974487},
#  {'label': 'LABEL_1', 'score': 0.7064678072929382},
#  {'label': 'LABEL_0', 'score': 0.9367827773094177},
#  {'label': 'LABEL_2', 'score': 0.9182124733924866},
#  {'label': 'LABEL_0', 'score': 0.8675987720489502},
#  {'label': 'LABEL_0', 'score': 0.7654778957366943},
#  {'label': 'LABEL_0', 'score': 0.9951813817024231},
#  {'label': 'LABEL_0', 'score': 0.6173270344734192},
#  {'label': 'LABEL_0', 'score': 0.9931508302688599},
#  {'label': 'LABEL_0', 'score': 0.9964802861213684},
#  {'label': 'LABEL_1', 'score': 0.9057809710502625},
#  {'label': 'LABEL_0', 'score': 0.9926372766494751},
#  {'label': 'LABEL_0', 'score': 0.9932733774185181},
#  {'label': 'LABEL_0', 'score': 0.9953546524047852},
#  {'label': 'LABEL_2', 'score': 0.8029432892799377},
#  {'label': 'LABEL_0', 'score': 0.9736488461494446},
#  {'label': 'LABEL_0', 'score': 0.9964229464530945},
#  {'label': 'LABEL_2', 'score': 0.912642240524292},
#  {'label': 'LABEL_0', 'score': 0.9958586096763611},
#  {'label': 'LABEL_0', 'score': 0.994941234588623},
#  {'label': 'LABEL_2', 'score': 0.8063029050827026},
#  {'label': 'LABEL_2', 'score': 0.938807487487793},
#  {'label': 'LABEL_0', 'score': 0.9663660526275635},
#  {'label': 'LABEL_0', 'score': 0.9688946008682251},
#  {'label': 'LABEL_2', 'score': 0.9010672569274902},
#  {'label': 'LABEL_0', 'score': 0.9947894811630249},
#  {'label': 'LABEL_1', 'score': 0.9786898493766785},
#  {'label': 'LABEL_0', 'score': 0.7386636137962341},
#  {'label': 'LABEL_2', 'score': 0.75517338514328},
#  {'label': 'LABEL_0', 'score': 0.9936810731887817},
#  {'label': 'LABEL_0', 'score': 0.9836791157722473},
#  {'label': 'LABEL_0', 'score': 0.8903208374977112},
#  {'label': 'LABEL_0', 'score': 0.9959064722061157},
#  {'label': 'LABEL_0', 'score': 0.6541630625724792},
#  {'label': 'LABEL_2', 'score': 0.9620183706283569},
#  {'label': 'LABEL_1', 'score': 0.9490503668785095},
#  {'label': 'LABEL_0', 'score': 0.9963504076004028},
#  {'label': 'LABEL_1', 'score': 0.9731950163841248},
#  {'label': 'LABEL_2', 'score': 0.7986540794372559},
#  {'label': 'LABEL_2', 'score': 0.980991005897522},
#  {'label': 'LABEL_0', 'score': 0.6014688014984131},
#  {'label': 'LABEL_0', 'score': 0.997043788433075},
#  {'label': 'LABEL_0', 'score': 0.9187496900558472},
#  {'label': 'LABEL_2', 'score': 0.9763281941413879},
#  {'label': 'LABEL_0', 'score': 0.9937134385108948},
#  {'label': 'LABEL_0', 'score': 0.7947238087654114},
#  {'label': 'LABEL_0', 'score': 0.9853726029396057},
#  {'label': 'LABEL_1', 'score': 0.9320428967475891},
#  {'label': 'LABEL_2', 'score': 0.9710702896118164},
#  {'label': 'LABEL_2', 'score': 0.6396035552024841},
#  {'label': 'LABEL_0', 'score': 0.98887038230896},
#  {'label': 'LABEL_0', 'score': 0.9924753308296204},
#  {'label': 'LABEL_0', 'score': 0.9449313282966614},
#  {'label': 'LABEL_0', 'score': 0.9959239959716797},
#  {'label': 'LABEL_2', 'score': 0.9649704694747925},
#  {'label': 'LABEL_2', 'score': 0.8710134625434875},
#  {'label': 'LABEL_2', 'score': 0.9832267165184021},
#  {'label': 'LABEL_0', 'score': 0.9945641756057739},
#  {'label': 'LABEL_0', 'score': 0.995558500289917},
#  {'label': 'LABEL_0', 'score': 0.9770792126655579},
#  {'label': 'LABEL_0', 'score': 0.488429456949234},
#  {'label': 'LABEL_2', 'score': 0.980939507484436},
#  {'label': 'LABEL_0', 'score': 0.9951456189155579},
#  {'label': 'LABEL_0', 'score': 0.9920786023139954},
#  {'label': 'LABEL_2', 'score': 0.91910719871521},
#  {'label': 'LABEL_2', 'score': 0.979577362537384},
#  {'label': 'LABEL_0', 'score': 0.9941440224647522},
#  {'label': 'LABEL_0', 'score': 0.9712513089179993},
#  {'label': 'LABEL_1', 'score': 0.33924826979637146},
#  {'label': 'LABEL_1', 'score': 0.7827062010765076},
#  {'label': 'LABEL_0', 'score': 0.8786603212356567},
#  {'label': 'LABEL_0', 'score': 0.9961026906967163},
#  {'label': 'LABEL_0', 'score': 0.8818047642707825},
#  {'label': 'LABEL_0', 'score': 0.9930567741394043},
#  {'label': 'LABEL_1', 'score': 0.9673521518707275},
#  {'label': 'LABEL_0', 'score': 0.9401781558990479},
#  {'label': 'LABEL_0', 'score': 0.9148690104484558},
#  {'label': 'LABEL_0', 'score': 0.9916961789131165},
#  {'label': 'LABEL_0', 'score': 0.9176491498947144},
#  {'label': 'LABEL_0', 'score': 0.9935792684555054},
#  {'label': 'LABEL_0', 'score': 0.963156521320343},
#  {'label': 'LABEL_0', 'score': 0.922072172164917},
#  {'label': 'LABEL_2', 'score': 0.9856939315795898},
#  {'label': 'LABEL_0', 'score': 0.9836094379425049},
#  {'label': 'LABEL_0', 'score': 0.9688196182250977},
#  {'label': 'LABEL_0', 'score': 0.9880793690681458},
#  {'label': 'LABEL_0', 'score': 0.993766188621521},
#  {'label': 'LABEL_2', 'score': 0.9478029608726501},
#  {'label': 'LABEL_0', 'score': 0.9964922070503235},
#  {'label': 'LABEL_0', 'score': 0.9890187978744507},
#  {'label': 'LABEL_0', 'score': 0.9966251850128174},
#  {'label': 'LABEL_2', 'score': 0.6329762935638428},
#  {'label': 'LABEL_2', 'score': 0.9786707758903503},
#  {'label': 'LABEL_2', 'score': 0.9631922841072083},
#  {'label': 'LABEL_0', 'score': 0.9951607584953308},
#  {'label': 'LABEL_0', 'score': 0.9883415102958679},
#  {'label': 'LABEL_1', 'score': 0.9651110172271729},
#  {'label': 'LABEL_0', 'score': 0.9175276160240173},
#  {'label': 'LABEL_0', 'score': 0.9962300658226013},
#  {'label': 'LABEL_0', 'score': 0.8205145597457886},
#  {'label': 'LABEL_2', 'score': 0.9859841465950012},
#  {'label': 'LABEL_0', 'score': 0.9909580945968628},
#  {'label': 'LABEL_0', 'score': 0.9926590323448181},
#  {'label': 'LABEL_0', 'score': 0.4940357804298401},
#  {'label': 'LABEL_0', 'score': 0.8405284285545349},
#  {'label': 'LABEL_2', 'score': 0.9632781744003296},
#  {'label': 'LABEL_0', 'score': 0.7894306778907776},
#  {'label': 'LABEL_0', 'score': 0.9225562214851379},
#  {'label': 'LABEL_0', 'score': 0.7940797805786133},
#  {'label': 'LABEL_0', 'score': 0.8379126787185669},
#  {'label': 'LABEL_0', 'score': 0.9942415952682495},
#  {'label': 'LABEL_2', 'score': 0.9543775916099548},
#  {'label': 'LABEL_0', 'score': 0.99676513671875},
#  {'label': 'LABEL_2', 'score': 0.6665729284286499},
#  {'label': 'LABEL_1', 'score': 0.9557821154594421},
#  {'label': 'LABEL_0', 'score': 0.9866347908973694},
#  {'label': 'LABEL_1', 'score': 0.9681674838066101},
#  {'label': 'LABEL_2', 'score': 0.9555449485778809},
#  {'label': 'LABEL_1', 'score': 0.927174985408783},
#  {'label': 'LABEL_2', 'score': 0.9533864259719849},
#  {'label': 'LABEL_0', 'score': 0.9947612881660461},
#  {'label': 'LABEL_0', 'score': 0.7182019948959351},
#  {'label': 'LABEL_2', 'score': 0.8746130466461182},
#  {'label': 'LABEL_1', 'score': 0.934276282787323},
#  {'label': 'LABEL_0', 'score': 0.8485396504402161},
#  {'label': 'LABEL_0', 'score': 0.9962798953056335},
#  {'label': 'LABEL_0', 'score': 0.9463537931442261},
#  {'label': 'LABEL_1', 'score': 0.9363600611686707},
#  {'label': 'LABEL_2', 'score': 0.9610633850097656},
#  {'label': 'LABEL_0', 'score': 0.9958926439285278},
#  {'label': 'LABEL_2', 'score': 0.9863561391830444},
#  {'label': 'LABEL_2', 'score': 0.47454607486724854},
#  {'label': 'LABEL_1', 'score': 0.9124327898025513},
#  {'label': 'LABEL_0', 'score': 0.9836192727088928},
#  {'label': 'LABEL_0', 'score': 0.9963818788528442},
#  {'label': 'LABEL_0', 'score': 0.9945389628410339},
#  {'label': 'LABEL_0', 'score': 0.9869220852851868},
#  {'label': 'LABEL_1', 'score': 0.8594180941581726},
#  {'label': 'LABEL_0', 'score': 0.9957143664360046},
#  {'label': 'LABEL_1', 'score': 0.6788459420204163},
#  {'label': 'LABEL_0', 'score': 0.9969635605812073},
#  {'label': 'LABEL_0', 'score': 0.9966527819633484},
#  {'label': 'LABEL_1', 'score': 0.972357988357544},
#  {'label': 'LABEL_2', 'score': 0.5358126759529114},
#  {'label': 'LABEL_2', 'score': 0.9674042463302612},
#  {'label': 'LABEL_0', 'score': 0.9888768792152405},
#  {'label': 'LABEL_2', 'score': 0.747150182723999},
#  {'label': 'LABEL_2', 'score': 0.9713155031204224},
#  {'label': 'LABEL_2', 'score': 0.959917426109314},
#  {'label': 'LABEL_0', 'score': 0.9948693513870239},
#  {'label': 'LABEL_0', 'score': 0.9251744151115417},
#  {'label': 'LABEL_2', 'score': 0.6583476662635803},
#  {'label': 'LABEL_0', 'score': 0.9927271604537964},
#  {'label': 'LABEL_0', 'score': 0.9939496517181396},
#  {'label': 'LABEL_1', 'score': 0.8375765681266785},
#  {'label': 'LABEL_0', 'score': 0.9585492610931396},
#  {'label': 'LABEL_2', 'score': 0.7613633871078491},
#  {'label': 'LABEL_0', 'score': 0.8061338663101196},
#  {'label': 'LABEL_1', 'score': 0.9432286620140076},
#  {'label': 'LABEL_0', 'score': 0.9913401007652283},
#  {'label': 'LABEL_0', 'score': 0.9967749714851379},
#  {'label': 'LABEL_0', 'score': 0.9958464503288269},
#  {'label': 'LABEL_0', 'score': 0.75845867395401},
#  {'label': 'LABEL_0', 'score': 0.9813253879547119},
#  {'label': 'LABEL_0', 'score': 0.9955710768699646},
#  {'label': 'LABEL_0', 'score': 0.9970172643661499},
#  {'label': 'LABEL_0', 'score': 0.9942182302474976},
#  {'label': 'LABEL_0', 'score': 0.9918740391731262},
#  {'label': 'LABEL_0', 'score': 0.9961751699447632},
#  {'label': 'LABEL_2', 'score': 0.9595205187797546},
#  {'label': 'LABEL_0', 'score': 0.9709445238113403},
#  {'label': 'LABEL_0', 'score': 0.9838137626647949},
#  {'label': 'LABEL_0', 'score': 0.9666056632995605},
#  {'label': 'LABEL_2', 'score': 0.6310551762580872},
#  {'label': 'LABEL_2', 'score': 0.7231108546257019},
#  {'label': 'LABEL_0', 'score': 0.9792143106460571},
#  {'label': 'LABEL_1', 'score': 0.6445461511611938},
#  {'label': 'LABEL_0', 'score': 0.9449546337127686},
#  {'label': 'LABEL_0', 'score': 0.9945118427276611},
#  {'label': 'LABEL_2', 'score': 0.9435355067253113},
#  {'label': 'LABEL_0', 'score': 0.9922260046005249},
#  {'label': 'LABEL_2', 'score': 0.9549427032470703},
#  {'label': 'LABEL_1', 'score': 0.9409747123718262},
#  {'label': 'LABEL_0', 'score': 0.6866847276687622},
#  {'label': 'LABEL_1', 'score': 0.7575897574424744},
#  {'label': 'LABEL_2', 'score': 0.4947497248649597},
#  {'label': 'LABEL_1', 'score': 0.8637533783912659},
#  {'label': 'LABEL_0', 'score': 0.9850892424583435},
#  {'label': 'LABEL_0', 'score': 0.8767514824867249},
#  {'label': 'LABEL_0', 'score': 0.9947564601898193},
#  {'label': 'LABEL_1', 'score': 0.8157868981361389},
#  {'label': 'LABEL_0', 'score': 0.9951748847961426},
#  {'label': 'LABEL_2', 'score': 0.8880589008331299},
#  {'label': 'LABEL_0', 'score': 0.9960967898368835},
#  {'label': 'LABEL_0', 'score': 0.8033843636512756},
#  {'label': 'LABEL_0', 'score': 0.9890874624252319},
#  {'label': 'LABEL_0', 'score': 0.9945849776268005},
#  {'label': 'LABEL_1', 'score': 0.971421480178833},
#  {'label': 'LABEL_0', 'score': 0.9947969317436218},
#  {'label': 'LABEL_2', 'score': 0.6446759104728699},
#  {'label': 'LABEL_2', 'score': 0.9720932841300964},
#  {'label': 'LABEL_0', 'score': 0.9947500824928284},
#  {'label': 'LABEL_0', 'score': 0.9962291121482849},
#  {'label': 'LABEL_0', 'score': 0.9664276242256165},
#  {'label': 'LABEL_0', 'score': 0.9958041310310364},
#  {'label': 'LABEL_0', 'score': 0.9967687129974365},
#  {'label': 'LABEL_0', 'score': 0.9939789772033691},
#  {'label': 'LABEL_1', 'score': 0.9738257527351379},
#  {'label': 'LABEL_1', 'score': 0.8506141901016235},
#  {'label': 'LABEL_0', 'score': 0.9830295443534851},
#  {'label': 'LABEL_0', 'score': 0.729927659034729},
#  {'label': 'LABEL_0', 'score': 0.987184464931488},
#  {'label': 'LABEL_0', 'score': 0.9949576258659363},
#  {'label': 'LABEL_0', 'score': 0.9955880641937256},
#  {'label': 'LABEL_0', 'score': 0.9965282082557678},
#  {'label': 'LABEL_1', 'score': 0.9570128321647644},
#  {'label': 'LABEL_0', 'score': 0.8249472975730896},
#  {'label': 'LABEL_0', 'score': 0.9787367582321167},
#  {'label': 'LABEL_1', 'score': 0.9733938574790955},
#  {'label': 'LABEL_0', 'score': 0.911490261554718},
#  {'label': 'LABEL_0', 'score': 0.9739193320274353},
#  {'label': 'LABEL_0', 'score': 0.9969134330749512},
#  {'label': 'LABEL_0', 'score': 0.8797019124031067},
#  {'label': 'LABEL_1', 'score': 0.9222038388252258},
#  {'label': 'LABEL_0', 'score': 0.9859868884086609},
#  {'label': 'LABEL_2', 'score': 0.9563397765159607},
#  {'label': 'LABEL_0', 'score': 0.9922617673873901},
#  {'label': 'LABEL_0', 'score': 0.9959235191345215},
#  {'label': 'LABEL_1', 'score': 0.9739670753479004},
#  {'label': 'LABEL_1', 'score': 0.9482988715171814},
#  {'label': 'LABEL_0', 'score': 0.8770142793655396},
#  {'label': 'LABEL_0', 'score': 0.9838736653327942},
#  {'label': 'LABEL_0', 'score': 0.9935809373855591},
#  {'label': 'LABEL_2', 'score': 0.9632053971290588},
#  {'label': 'LABEL_1', 'score': 0.747423529624939},
#  {'label': 'LABEL_2', 'score': 0.9732133746147156},
#  {'label': 'LABEL_0', 'score': 0.9941226840019226},
#  {'label': 'LABEL_2', 'score': 0.9695405960083008},
#  {'label': 'LABEL_0', 'score': 0.9096361398696899},
#  {'label': 'LABEL_2', 'score': 0.9442263841629028},
#  {'label': 'LABEL_0', 'score': 0.7526334524154663},
#  {'label': 'LABEL_0', 'score': 0.9855777621269226},
#  {'label': 'LABEL_0', 'score': 0.9515407085418701},
#  {'label': 'LABEL_0', 'score': 0.9958786964416504},
#  {'label': 'LABEL_0', 'score': 0.9889947772026062},
#  {'label': 'LABEL_0', 'score': 0.9924708604812622},
#  {'label': 'LABEL_2', 'score': 0.4936922788619995},
#  {'label': 'LABEL_0', 'score': 0.9957602620124817},
#  {'label': 'LABEL_0', 'score': 0.9890143275260925},
#  {'label': 'LABEL_2', 'score': 0.8098212480545044},
#  {'label': 'LABEL_0', 'score': 0.9794254899024963},
#  {'label': 'LABEL_0', 'score': 0.996446430683136},
#  {'label': 'LABEL_1', 'score': 0.8744663596153259},
#  {'label': 'LABEL_0', 'score': 0.9441103935241699},
#  {'label': 'LABEL_0', 'score': 0.8938019871711731},
#  {'label': 'LABEL_2', 'score': 0.9763340950012207},
#  {'label': 'LABEL_2', 'score': 0.6970670223236084},
#  {'label': 'LABEL_0', 'score': 0.9950129389762878},
#  {'label': 'LABEL_2', 'score': 0.6300584673881531},
#  {'label': 'LABEL_0', 'score': 0.9951189756393433},
#  {'label': 'LABEL_0', 'score': 0.995283305644989},
#  {'label': 'LABEL_0', 'score': 0.9944591522216797},
#  {'label': 'LABEL_0', 'score': 0.9946125745773315},
#  {'label': 'LABEL_0', 'score': 0.9910238981246948},
#  {'label': 'LABEL_2', 'score': 0.9877697825431824},
#  {'label': 'LABEL_1', 'score': 0.9773225784301758},
#  {'label': 'LABEL_1', 'score': 0.6277654767036438},
#  {'label': 'LABEL_0', 'score': 0.9915339350700378},
#  {'label': 'LABEL_0', 'score': 0.9950842261314392},
#  {'label': 'LABEL_2', 'score': 0.7078655362129211},
#  {'label': 'LABEL_2', 'score': 0.9574410319328308},
#  {'label': 'LABEL_0', 'score': 0.9823576211929321},
#  {'label': 'LABEL_2', 'score': 0.9615566730499268},
#  {'label': 'LABEL_1', 'score': 0.8246825337409973},
#  {'label': 'LABEL_2', 'score': 0.9781557321548462},
#  {'label': 'LABEL_0', 'score': 0.9945047497749329},
#  {'label': 'LABEL_0', 'score': 0.9655611515045166},
#  {'label': 'LABEL_0', 'score': 0.9927330017089844},
#  {'label': 'LABEL_0', 'score': 0.9949555993080139},
#  {'label': 'LABEL_2', 'score': 0.8049055337905884},
#  {'label': 'LABEL_0', 'score': 0.979564905166626},
#  {'label': 'LABEL_2', 'score': 0.9230550527572632},
#  {'label': 'LABEL_2', 'score': 0.5180966854095459},
#  {'label': 'LABEL_1', 'score': 0.921265184879303},
#  {'label': 'LABEL_0', 'score': 0.9960559606552124},
#  {'label': 'LABEL_0', 'score': 0.995084822177887},
#  {'label': 'LABEL_2', 'score': 0.9606882929801941},
#  {'label': 'LABEL_0', 'score': 0.7418654561042786},
#  {'label': 'LABEL_2', 'score': 0.9866077899932861},
#  {'label': 'LABEL_0', 'score': 0.9967959523200989},
#  {'label': 'LABEL_0', 'score': 0.7633631825447083},
#  {'label': 'LABEL_0', 'score': 0.9949052333831787},
#  {'label': 'LABEL_0', 'score': 0.9921202659606934},
#  {'label': 'LABEL_0', 'score': 0.99657142162323},
#  {'label': 'LABEL_2', 'score': 0.9515482783317566},
#  {'label': 'LABEL_0', 'score': 0.9879662394523621},
#  {'label': 'LABEL_0', 'score': 0.49116286635398865},
#  {'label': 'LABEL_1', 'score': 0.9390214085578918},
#  {'label': 'LABEL_0', 'score': 0.9638261795043945},
#  {'label': 'LABEL_0', 'score': 0.9805564880371094},
#  {'label': 'LABEL_0', 'score': 0.9857087135314941},
#  {'label': 'LABEL_0', 'score': 0.9958798885345459},
#  {'label': 'LABEL_2', 'score': 0.9551413059234619},
#  {'label': 'LABEL_1', 'score': 0.9542657732963562},
#  {'label': 'LABEL_2', 'score': 0.9415310025215149},
#  {'label': 'LABEL_1', 'score': 0.9046165347099304},
#  {'label': 'LABEL_0', 'score': 0.9533584713935852},
#  {'label': 'LABEL_0', 'score': 0.9967281818389893},
#  {'label': 'LABEL_2', 'score': 0.648705005645752},
#  {'label': 'LABEL_0', 'score': 0.9723840951919556},
#  {'label': 'LABEL_0', 'score': 0.9959192872047424},
#  {'label': 'LABEL_1', 'score': 0.9758388996124268},
#  {'label': 'LABEL_0', 'score': 0.9943943023681641},
#  {'label': 'LABEL_0', 'score': 0.9919930696487427},
#  {'label': 'LABEL_0', 'score': 0.7836672067642212},
#  {'label': 'LABEL_1', 'score': 0.8769887685775757},
#  {'label': 'LABEL_0', 'score': 0.9929322004318237},
#  {'label': 'LABEL_0', 'score': 0.9955174326896667},
#  {'label': 'LABEL_2', 'score': 0.625723123550415},
#  {'label': 'LABEL_1', 'score': 0.9482042789459229},
#  {'label': 'LABEL_0', 'score': 0.9964637160301208},
#  {'label': 'LABEL_0', 'score': 0.9315727949142456},
#  {'label': 'LABEL_0', 'score': 0.7406143546104431},
#  {'label': 'LABEL_2', 'score': 0.9565832018852234},
#  {'label': 'LABEL_0', 'score': 0.9873740077018738},
#  {'label': 'LABEL_0', 'score': 0.6458014249801636},
#  {'label': 'LABEL_0', 'score': 0.8795168995857239},
#  {'label': 'LABEL_0', 'score': 0.9959505796432495},
#  {'label': 'LABEL_2', 'score': 0.7057749629020691},
#  {'label': 'LABEL_1', 'score': 0.9646307229995728},
#  {'label': 'LABEL_2', 'score': 0.986599862575531},
#  {'label': 'LABEL_0', 'score': 0.9916979074478149},
#  {'label': 'LABEL_0', 'score': 0.9963973164558411},
#  {'label': 'LABEL_2', 'score': 0.7441062331199646},
#  {'label': 'LABEL_0', 'score': 0.9956982135772705},
#  {'label': 'LABEL_0', 'score': 0.993165910243988},
#  {'label': 'LABEL_0', 'score': 0.9944243431091309},
#  {'label': 'LABEL_1', 'score': 0.8912782073020935},
#  {'label': 'LABEL_2', 'score': 0.9537861943244934},
#  {'label': 'LABEL_2', 'score': 0.9580712914466858},
#  {'label': 'LABEL_0', 'score': 0.9903106093406677},
#  {'label': 'LABEL_2', 'score': 0.9604823589324951},
#  {'label': 'LABEL_1', 'score': 0.7778146862983704},
#  {'label': 'LABEL_0', 'score': 0.9761333465576172},
#  {'label': 'LABEL_0', 'score': 0.9962215423583984},
#  {'label': 'LABEL_0', 'score': 0.9965908527374268},
#  {'label': 'LABEL_0', 'score': 0.9961711764335632},
#  {'label': 'LABEL_2', 'score': 0.6166971325874329},
#  {'label': 'LABEL_2', 'score': 0.9260571599006653},
#  {'label': 'LABEL_0', 'score': 0.9952869415283203},
#  {'label': 'LABEL_0', 'score': 0.9853695631027222},
#  {'label': 'LABEL_0', 'score': 0.9342049360275269},
#  {'label': 'LABEL_2', 'score': 0.8629579544067383},
#  {'label': 'LABEL_0', 'score': 0.9766963720321655},
#  {'label': 'LABEL_2', 'score': 0.9320495128631592},
#  {'label': 'LABEL_0', 'score': 0.9928650856018066},
#  {'label': 'LABEL_2', 'score': 0.42611607909202576},
#  {'label': 'LABEL_0', 'score': 0.9923532605171204},
#  {'label': 'LABEL_0', 'score': 0.9534522294998169},
#  {'label': 'LABEL_0', 'score': 0.9077399969100952},
#  {'label': 'LABEL_1', 'score': 0.9698043465614319},
#  {'label': 'LABEL_0', 'score': 0.8009334802627563},
#  {'label': 'LABEL_0', 'score': 0.8648149371147156},
#  {'label': 'LABEL_1', 'score': 0.9603810906410217},
#  {'label': 'LABEL_2', 'score': 0.9715421795845032},
#  {'label': 'LABEL_0', 'score': 0.9954741597175598},
#  {'label': 'LABEL_0', 'score': 0.9949284791946411},
#  {'label': 'LABEL_1', 'score': 0.6545043587684631},
#  {'label': 'LABEL_0', 'score': 0.9970640540122986},
#  {'label': 'LABEL_0', 'score': 0.9852863550186157},
#  {'label': 'LABEL_0', 'score': 0.9921199083328247},
#  {'label': 'LABEL_0', 'score': 0.9738370776176453},
#  {'label': 'LABEL_0', 'score': 0.9961162805557251},
#  {'label': 'LABEL_0', 'score': 0.9952351450920105},
#  {'label': 'LABEL_2', 'score': 0.9092050194740295},
#  {'label': 'LABEL_2', 'score': 0.6333420872688293},
#  {'label': 'LABEL_2', 'score': 0.9628191590309143},
#  {'label': 'LABEL_0', 'score': 0.9909692406654358},
#  {'label': 'LABEL_2', 'score': 0.7344939112663269},
#  {'label': 'LABEL_0', 'score': 0.9963279366493225},
#  {'label': 'LABEL_0', 'score': 0.9550069570541382},
#  {'label': 'LABEL_0', 'score': 0.990730345249176},
#  {'label': 'LABEL_0', 'score': 0.9900418519973755},
#  {'label': 'LABEL_0', 'score': 0.5497351288795471},
#  {'label': 'LABEL_0', 'score': 0.9864110350608826},
#  {'label': 'LABEL_0', 'score': 0.9892226457595825},
#  {'label': 'LABEL_2', 'score': 0.6941912174224854},
#  {'label': 'LABEL_2', 'score': 0.9027670621871948},
#  {'label': 'LABEL_2', 'score': 0.9701899886131287},
#  {'label': 'LABEL_1', 'score': 0.9487515687942505},
#  {'label': 'LABEL_0', 'score': 0.9108442664146423},
#  {'label': 'LABEL_1', 'score': 0.9708676338195801},
#  {'label': 'LABEL_1', 'score': 0.9303758144378662},
#  {'label': 'LABEL_2', 'score': 0.8677103519439697},
#  {'label': 'LABEL_1', 'score': 0.9030197262763977},
#  {'label': 'LABEL_0', 'score': 0.8611470460891724},
#  {'label': 'LABEL_0', 'score': 0.9961997866630554},
#  {'label': 'LABEL_0', 'score': 0.9962360262870789},
#  {'label': 'LABEL_0', 'score': 0.9954244494438171},
#  {'label': 'LABEL_1', 'score': 0.934844970703125},
#  {'label': 'LABEL_1', 'score': 0.9754320979118347},
#  {'label': 'LABEL_0', 'score': 0.9941567182540894},
#  {'label': 'LABEL_0', 'score': 0.9093632698059082},
#  {'label': 'LABEL_0', 'score': 0.9870432019233704},
#  {'label': 'LABEL_0', 'score': 0.9942470788955688},
#  {'label': 'LABEL_2', 'score': 0.9615798592567444},
#  {'label': 'LABEL_1', 'score': 0.9584242105484009},
#  {'label': 'LABEL_2', 'score': 0.5649849772453308},
#  {'label': 'LABEL_0', 'score': 0.5045166611671448},
#  {'label': 'LABEL_0', 'score': 0.8708623647689819},
#  {'label': 'LABEL_0', 'score': 0.9967507123947144},
#  {'label': 'LABEL_0', 'score': 0.8907667398452759},
#  {'label': 'LABEL_2', 'score': 0.7326675057411194},
#  {'label': 'LABEL_0', 'score': 0.9769203662872314},
#  {'label': 'LABEL_0', 'score': 0.9872222542762756},
#  {'label': 'LABEL_1', 'score': 0.9674726724624634},
#  {'label': 'LABEL_1', 'score': 0.5945039987564087},
#  {'label': 'LABEL_0', 'score': 0.9841073751449585},
#  {'label': 'LABEL_2', 'score': 0.8251396417617798},
#  {'label': 'LABEL_0', 'score': 0.8713563084602356},
#  {'label': 'LABEL_0', 'score': 0.9865019917488098},
#  {'label': 'LABEL_0', 'score': 0.46413904428482056},
#  {'label': 'LABEL_0', 'score': 0.7553340196609497},
#  {'label': 'LABEL_0', 'score': 0.9951527118682861},
#  {'label': 'LABEL_0', 'score': 0.8973178267478943},
#  {'label': 'LABEL_0', 'score': 0.978428304195404},
#  {'label': 'LABEL_0', 'score': 0.8927731513977051},
#  {'label': 'LABEL_0', 'score': 0.9940159320831299},
#  {'label': 'LABEL_1', 'score': 0.7029649019241333},
#  {'label': 'LABEL_0', 'score': 0.9820605516433716},
#  {'label': 'LABEL_0', 'score': 0.9770950078964233},
#  {'label': 'LABEL_0', 'score': 0.9930777549743652},
#  {'label': 'LABEL_2', 'score': 0.5614873170852661},
#  {'label': 'LABEL_0', 'score': 0.9608373641967773},
#  {'label': 'LABEL_0', 'score': 0.9920563101768494},
#  {'label': 'LABEL_1', 'score': 0.4174169898033142},
#  {'label': 'LABEL_0', 'score': 0.7813317179679871},
#  {'label': 'LABEL_0', 'score': 0.962859570980072},
#  {'label': 'LABEL_2', 'score': 0.9855948686599731},
#  {'label': 'LABEL_2', 'score': 0.9735002517700195},
#  {'label': 'LABEL_0', 'score': 0.9920967817306519},
#  {'label': 'LABEL_0', 'score': 0.9694883823394775},
#  {'label': 'LABEL_0', 'score': 0.9530045390129089},
#  {'label': 'LABEL_1', 'score': 0.9837117791175842},
#  {'label': 'LABEL_0', 'score': 0.9035386443138123},
#  {'label': 'LABEL_0', 'score': 0.6230124831199646},
#  {'label': 'LABEL_2', 'score': 0.9438807368278503},
#  {'label': 'LABEL_0', 'score': 0.9910836219787598},
#  {'label': 'LABEL_0', 'score': 0.995647132396698},
#  {'label': 'LABEL_0', 'score': 0.9910599589347839},
#  {'label': 'LABEL_0', 'score': 0.9965564012527466},
#  {'label': 'LABEL_2', 'score': 0.672199547290802},
#  {'label': 'LABEL_0', 'score': 0.9524400234222412},
#  {'label': 'LABEL_0', 'score': 0.9945375323295593},
#  {'label': 'LABEL_1', 'score': 0.9087409973144531},
#  {'label': 'LABEL_0', 'score': 0.9958989024162292},
#  {'label': 'LABEL_1', 'score': 0.6525115966796875},
#  {'label': 'LABEL_0', 'score': 0.8490669131278992},
#  {'label': 'LABEL_0', 'score': 0.8919787406921387},
#  {'label': 'LABEL_2', 'score': 0.9535830616950989},
#  {'label': 'LABEL_1', 'score': 0.9785547852516174},
#  {'label': 'LABEL_2', 'score': 0.9857097864151001},
#  {'label': 'LABEL_1', 'score': 0.5663772821426392},
#  {'label': 'LABEL_2', 'score': 0.7606516480445862},
#  {'label': 'LABEL_2', 'score': 0.9549092054367065},
#  {'label': 'LABEL_1', 'score': 0.9044048190116882},
#  {'label': 'LABEL_0', 'score': 0.9963429570198059},
#  {'label': 'LABEL_2', 'score': 0.9275904893875122},
#  {'label': 'LABEL_2', 'score': 0.9642828702926636},
#  {'label': 'LABEL_0', 'score': 0.9808542728424072},
#  {'label': 'LABEL_2', 'score': 0.5837193727493286},
#  {'label': 'LABEL_0', 'score': 0.9932830333709717},
#  {'label': 'LABEL_2', 'score': 0.8943681716918945},
#  {'label': 'LABEL_0', 'score': 0.9933801889419556},
#  {'label': 'LABEL_2', 'score': 0.9227598905563354},
#  {'label': 'LABEL_1', 'score': 0.6609637141227722},
#  {'label': 'LABEL_0', 'score': 0.9927346706390381},
#  {'label': 'LABEL_2', 'score': 0.5420560836791992},
#  {'label': 'LABEL_0', 'score': 0.9904218912124634},
#  {'label': 'LABEL_0', 'score': 0.9964970946311951},
#  {'label': 'LABEL_2', 'score': 0.9869317412376404},
#  {'label': 'LABEL_2', 'score': 0.9788597822189331},
#  {'label': 'LABEL_2', 'score': 0.528020441532135},
#  {'label': 'LABEL_0', 'score': 0.9909917116165161},
#  {'label': 'LABEL_0', 'score': 0.9943490624427795},
#  {'label': 'LABEL_0', 'score': 0.987293004989624},
#  {'label': 'LABEL_1', 'score': 0.968690037727356},
#  {'label': 'LABEL_1', 'score': 0.9269846677780151},
#  {'label': 'LABEL_0', 'score': 0.9918980598449707},
#  {'label': 'LABEL_1', 'score': 0.753217339515686},
#  {'label': 'LABEL_2', 'score': 0.9814454913139343},
#  {'label': 'LABEL_0', 'score': 0.5555602312088013},
#  {'label': 'LABEL_0', 'score': 0.9967165589332581},
#  {'label': 'LABEL_0', 'score': 0.9766952395439148},
#  {'label': 'LABEL_2', 'score': 0.9413554072380066},
#  {'label': 'LABEL_1', 'score': 0.9514750838279724},
#  {'label': 'LABEL_0', 'score': 0.991919994354248},
#  {'label': 'LABEL_0', 'score': 0.9964867830276489},
#  {'label': 'LABEL_0', 'score': 0.996160626411438},
#  {'label': 'LABEL_1', 'score': 0.9763190150260925},
#  {'label': 'LABEL_2', 'score': 0.964415431022644},
#  {'label': 'LABEL_0', 'score': 0.9966487288475037},
#  {'label': 'LABEL_0', 'score': 0.9742083549499512},
#  {'label': 'LABEL_0', 'score': 0.9932725429534912},
#  {'label': 'LABEL_0', 'score': 0.9768546223640442},
#  {'label': 'LABEL_0', 'score': 0.9669945240020752},
#  {'label': 'LABEL_0', 'score': 0.9610750675201416},
#  {'label': 'LABEL_2', 'score': 0.977331817150116},
#  {'label': 'LABEL_1', 'score': 0.8185296654701233},
#  {'label': 'LABEL_0', 'score': 0.9512766599655151},
#  {'label': 'LABEL_0', 'score': 0.9650927186012268},
#  {'label': 'LABEL_0', 'score': 0.9959867596626282},
#  {'label': 'LABEL_0', 'score': 0.9802649021148682},
#  {'label': 'LABEL_2', 'score': 0.9839853644371033},
#  {'label': 'LABEL_0', 'score': 0.9478747248649597},
#  {'label': 'LABEL_1', 'score': 0.8992229104042053},
#  {'label': 'LABEL_0', 'score': 0.9934613704681396},
#  {'label': 'LABEL_2', 'score': 0.7653349041938782},
#  {'label': 'LABEL_1', 'score': 0.9224134683609009},
#  {'label': 'LABEL_0', 'score': 0.9970971345901489},
#  {'label': 'LABEL_1', 'score': 0.9421340227127075},
#  {'label': 'LABEL_0', 'score': 0.9962582588195801},
#  {'label': 'LABEL_0', 'score': 0.9962249994277954},
#  {'label': 'LABEL_0', 'score': 0.9964403510093689},
#  {'label': 'LABEL_0', 'score': 0.9955476522445679},
#  {'label': 'LABEL_0', 'score': 0.9187478423118591},
#  {'label': 'LABEL_1', 'score': 0.9853864908218384},
#  {'label': 'LABEL_2', 'score': 0.845965564250946},
#  {'label': 'LABEL_0', 'score': 0.8926293849945068},
#  {'label': 'LABEL_0', 'score': 0.9932310581207275},
#  {'label': 'LABEL_0', 'score': 0.9942082166671753},
#  {'label': 'LABEL_0', 'score': 0.5687581896781921},
#  {'label': 'LABEL_0', 'score': 0.9957259893417358},
#  {'label': 'LABEL_0', 'score': 0.9924395084381104},
#  {'label': 'LABEL_0', 'score': 0.9958427548408508},
#  {'label': 'LABEL_0', 'score': 0.9742607474327087},
#  {'label': 'LABEL_0', 'score': 0.9921219348907471},
#  {'label': 'LABEL_2', 'score': 0.9854834079742432},
#  {'label': 'LABEL_2', 'score': 0.8705677390098572},
#  {'label': 'LABEL_0', 'score': 0.9786215424537659},
#  {'label': 'LABEL_0', 'score': 0.6331006288528442},
#  {'label': 'LABEL_0', 'score': 0.6543498635292053},
#  {'label': 'LABEL_0', 'score': 0.9925436973571777},
#  {'label': 'LABEL_2', 'score': 0.8624762892723083},
#  {'label': 'LABEL_0', 'score': 0.9965057373046875},
#  {'label': 'LABEL_0', 'score': 0.9867866039276123},
#  {'label': 'LABEL_0', 'score': 0.9553650617599487},
#  {'label': 'LABEL_1', 'score': 0.9644423723220825},
#  {'label': 'LABEL_0', 'score': 0.9866834282875061},
#  {'label': 'LABEL_0', 'score': 0.9960988759994507},
#  {'label': 'LABEL_0', 'score': 0.9879484176635742},
#  {'label': 'LABEL_1', 'score': 0.9463150501251221},
#  {'label': 'LABEL_0', 'score': 0.9278726577758789},
#  {'label': 'LABEL_1', 'score': 0.96635901927948},
#  {'label': 'LABEL_0', 'score': 0.9961947202682495},
#  {'label': 'LABEL_0', 'score': 0.6457548141479492},
#  {'label': 'LABEL_0', 'score': 0.973042368888855},
#  {'label': 'LABEL_2', 'score': 0.9854106903076172},
#  {'label': 'LABEL_0', 'score': 0.9929510354995728},
#  {'label': 'LABEL_0', 'score': 0.9954047203063965},
#  {'label': 'LABEL_2', 'score': 0.8109372854232788},
#  {'label': 'LABEL_0', 'score': 0.9838109612464905},
#  {'label': 'LABEL_0', 'score': 0.994159460067749},
#  {'label': 'LABEL_0', 'score': 0.9962661862373352},
#  {'label': 'LABEL_1', 'score': 0.9762344360351562},
#  {'label': 'LABEL_0', 'score': 0.9949294328689575},
#  {'label': 'LABEL_0', 'score': 0.9574108719825745},
#  {'label': 'LABEL_0', 'score': 0.9718719720840454},
#  {'label': 'LABEL_2', 'score': 0.5284378528594971},
#  ...]

# %%
def get_label(d):
    return int(d['label'].split('_')[1])

test_pred = [get_label(d) for d in test_pred]

# %%
test_pred[0:10]
# Out:
# [1, 1, 1, 1, 2, 0, 2, 2, 1, 0]

# %%
print("acc:", accuracy_score(split['test']['label'], test_pred))
# Out:
# acc: 0.8280965391621129

# %%
print("f1:", f1_score(split['test']['label'], test_pred, average='macro'))
# Out:
# f1: 0.7815884850880779

# %%
#def plot_cm(cm):
 #   classes = ['negative', 'positive', 'neutral']

cm = confusion_matrix(split['test']['label'], test_pred, normalize='true')

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
